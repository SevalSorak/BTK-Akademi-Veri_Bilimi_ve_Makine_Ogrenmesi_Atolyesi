# %%
from pyspark.sql import SparkSession

# %%
sparkSession = SparkSession.builder \
        .config("spark.mongodb.input.uri","mongodb+srv://admin:MYR9gaf8y4N6btq@verimaratonu.ai1jo.mongodb.net/myFirstDatabase?retryWrites=true&w=majority") \
        .appName("MongoDB Spark Read").getOrCreate()

# %%
sparkSession
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=2695144408936499#setting/sparkui/0217-103633-djxcvr0s/driver-4991770259513737756">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
allitemsDF = spark.read.format("mongo").option("uri","mongodb+srv://admin:MYR9gaf8y4N6btq@verimaratonu.ai1jo.mongodb.net/myFirstDatabase?retryWrites=true&w=majority") \
            .option("database","verimaratonu").option("collection","alsallitems").load()

# %%
allitemsDF.show(truncate=False)
# Out:
# +--------------------------+-------+--------------------------------------------------------------------------------+
# |_id                       |movieId|recommendations                                                                 |
# +--------------------------+-------+--------------------------------------------------------------------------------+
# |{620e3ca3a2f36f1c05c594d0}|1      |[{464, 5.012614727020264}, {113, 4.981077194213867}, {543, 4.907954216003418}]  |
# |{620e3ca3a2f36f1c05c594d1}|13     |[{113, 3.831688165664673}, {564, 3.8125171661376953}, {298, 3.7101340293884277}]|
# |{620e3ca3a2f36f1c05c594d2}|22     |[{113, 4.366271018981934}, {145, 4.32979154586792}, {114, 4.256211757659912}]   |
# |{620e3ca3a2f36f1c05c594d3}|47     |[{546, 5.204338073730469}, {154, 5.177369117736816}, {46, 5.109932899475098}]   |
# |{620e3ca3a2f36f1c05c594d4}|52     |[{154, 4.571406841278076}, {160, 4.511392116546631}, {258, 4.482177734375}]     |
# ...

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
