# %%
from kafka import KafkaConsumer

# %%
consumer = KafkaConsumer('test-second',bootstrap_servers="159.223.188.228:9092",
             auto_offset_reset="earliest")

# %%
consumer.metrics()
# Out:
# Out[3]: {'kafka-metrics-count': {'count': 50.0},
#  'consumer-metrics': {'connection-close-rate': 0.0,
#   'connection-creation-rate': 0.026294038880114546,
#   'select-rate': 0.0,
#   'io-wait-time-ns-avg': 0.0,
#   'io-wait-ratio': 0.0,
#   'io-time-ns-avg': 0.0,
#   'io-ratio': 0.0,
#   'connection-count': 1.0,
#   'network-io-rate': 0.10517673212080131,
#   'outgoing-byte-rate': 1.7880040098876118,
#   'request-rate': 0.05258833736527705,
#   'request-size-avg': 34.0,
#   'request-size-max': 36.0,
#   'incoming-byte-rate': 49.616737678025565,
#   'response-rate': 0.05272765562769986,
#   'request-latency-avg': 88.96088600158691,
#   'request-latency-max': 100.85678100585938},
#  'consumer-node-metrics.node-bootstrap-0': {'outgoing-byte-rate': 1.7879984200946866,
#   'request-rate': 0.05258817363487678,
#   'request-size-avg': 34.0,
#   'request-size-max': 36.0,
#   'incoming-byte-rate': 49.616601312834284,
#   'response-rate': 0.05272751580327387,
# ...

# %%
for msg in consumer:
  print(msg.)
# Out:
# b"{'itemId':12345,'customerId':9876,'item':'Telefon','price':5000}"
